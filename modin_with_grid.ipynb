# %%
# !pip install modin[spreadsheet]
# !pip install modin-spreadsheet

# %%
import modin.pandas as pd
import numpy as np
import modin_spreadsheet as mss

# %%
df=pd.read_csv("iris.data")

# %%
df
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
col_opts = { 'editable': False }
col_defs = { 'A': { 'editable': True } }

# %%
mss.show_grid(df, column_options=col_opts, column_definitions=col_defs)
# Out:
# SpreadsheetWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': False,…

# %%
# ---- spreadsheet transformation history ----
unfiltered_df = df.copy()
# Remove rows
df.drop([], inplace=True)
unfiltered_df.drop([], inplace=True)

# %%
# ---- spreadsheet transformation history ----
unfiltered_df = df.copy()
# Filter columns
df = unfiltered_df[(unfiltered_df['5.1'] >= 5.578)&(unfiltered_df['3.5'] >= 3.168)].copy()
# Filter columns
df = unfiltered_df[(unfiltered_df['5.1'] >= 5.578)&(unfiltered_df['3.5'] >= 3.168)&(unfiltered_df['1.4'] >= 4.0875)].copy()
# Filter columns
df = unfiltered_df[(unfiltered_df['index'] >= 94)&(unfiltered_df['5.1'] >= 5.578)&(unfiltered_df['3.5'] >= 3.168)&(unfiltered_df['1.4'] >= 4.0875)].copy()
# Sort column
df.sort_values('5.1', ascending=True, inplace=True)
# Sort column
df.sort_values('3.5', ascending=True, inplace=True)
# Filter columns
df = unfiltered_df[(unfiltered_df['index'] >= 94)&(unfiltered_df['5.1'] >= 5.578)&(unfiltered_df['3.5'] >= 4.158)&(unfiltered_df['1.4'] >= 4.0875)].copy()
# Sort column
df.sort_values('3.5', ascending=True, inplace=True)
# Filter columns
df = unfiltered_df[(unfiltered_df['index'] >= 94)&(unfiltered_df['5.1'] >= 5.578)&(unfiltered_df['3.5'] >= 4.147)&(unfiltered_df['1.4'] >= 4.0875)].copy()
# Sort column
df.sort_values('3.5', ascending=True, inplace=True)
# Filter columns
df = unfiltered_df[(unfiltered_df['index'] >= 94)&(unfiltered_df['5.1'] >= 5.578)&(unfiltered_df['3.5'] >= 4.092)&(unfiltered_df['1.4'] >= 4.0875)].copy()
# Sort column
df.sort_values('3.5', ascending=True, inplace=True)
# Filter columns
df = unfiltered_df[(unfiltered_df['index'] >= 94)&(unfiltered_df['5.1'] >= 5.578)&(unfiltered_df['3.5'] >= 4.081)&(unfiltered_df['1.4'] >= 4.0875)].copy()
# Sort column
df.sort_values('3.5', ascending=True, inplace=True)
# Filter columns
df = unfiltered_df[(unfiltered_df['index'] >= 94)&(unfiltered_df['5.1'] >= 5.578)&(unfiltered_df['3.5'] >= 3.619)&(unfiltered_df['1.4'] >= 4.0875)].copy()
# Sort column
df.sort_values('3.5', ascending=True, inplace=True)
# Filter columns
df = unfiltered_df[(unfiltered_df['index'] >= 94)&(unfiltered_df['5.1'] >= 5.578)&(unfiltered_df['3.5'] >= 3.619)&(unfiltered_df['1.4'] >= 4.0875)&(unfiltered_df['Iris-setosa'].isin(['Iris-virginica']))].copy()
# Sort column
df.sort_values('3.5', ascending=True, inplace=True)
# Filter columns
df = unfiltered_df[(unfiltered_df['index'] >= 94)&(unfiltered_df['5.1'] >= 5.578)&(unfiltered_df['3.5'] >= 3.619)&(unfiltered_df['1.4'] >= 4.0875)&(unfiltered_df['0.2'] >= 2.002)&(unfiltered_df['Iris-setosa'].isin(['Iris-virginica']))].copy()
# Sort column
df.sort_values('3.5', ascending=True, inplace=True)
# Filter columns
df = unfiltered_df[(unfiltered_df['index'] >= 94)&(unfiltered_df['5.1'] >= 5.578)&(unfiltered_df['3.5'] >= 3.619)&(unfiltered_df['1.4'] >= 4.0875)&(unfiltered_df['0.2'] >= 2.018)&(unfiltered_df['Iris-setosa'].isin(['Iris-virginica']))].copy()
# Sort column
df.sort_values('3.5', ascending=True, inplace=True)
# Filter columns
df = unfiltered_df[(unfiltered_df['index'] >= 94)&(unfiltered_df['5.1'] >= 5.578)&(unfiltered_df['3.5'] >= 3.619)&(unfiltered_df['1.4'] >= 4.0875)&(unfiltered_df['0.2'] >= 2.019)&(unfiltered_df['Iris-setosa'].isin(['Iris-virginica']))].copy()
# Sort column
df.sort_values('3.5', ascending=True, inplace=True)
# Filter columns
df = unfiltered_df[(unfiltered_df['index'] >= 94)&(unfiltered_df['5.1'] >= 5.578)&(unfiltered_df['3.5'] >= 3.619)&(unfiltered_df['1.4'] >= 4.0875)&(unfiltered_df['0.2'] >= 2.051)&(unfiltered_df['Iris-setosa'].isin(['Iris-virginica']))].copy()
# Sort column
df.sort_values('3.5', ascending=True, inplace=True)
# Filter columns
df = unfiltered_df[(unfiltered_df['index'] >= 94)&(unfiltered_df['5.1'] >= 5.578)&(unfiltered_df['3.5'] >= 3.619)&(unfiltered_df['1.4'] >= 4.0875)&(unfiltered_df['0.2'] >= 2.053)&(unfiltered_df['Iris-setosa'].isin(['Iris-virginica']))].copy()
# Sort column
df.sort_values('3.5', ascending=True, inplace=True)
